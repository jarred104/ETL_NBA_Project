# %%
import pandas as pd
import unidecode

# %%
# File to Load
file_to_load = "player_stats_2019.csv"

# Read Purchasing File and store into Pandas data frame
player_data = pd.read_csv(file_to_load)

# %%
player_data.head()
# Out:
#    player_id player_lastname player_firstname  season pos  age   tm   g  gs  \
# 0  abrinal01         Abrines             Álex    2019  SG   25  OKC  31   2
# 1    acyqu01             Acy           Quincy    2019  PF   28  PHO  10   0
# 2  adamsja01           Adams           Jaylen    2019  PG   22  ATL  34   1
# 3  adamsst01           Adams           Steven    2019   C   25  OKC  80  80
# 4  adebaba01         Adebayo              Bam    2019   C   21  MIA  82  28
#
#      mp  ...  ft_perc  orb  drb  trb  ast  stl  blk  tov   pf   pts
# 0   588  ...    0.923    5   43   48   20   17    6   14   53   165
# 1   123  ...    0.700    3   22   25    8    1    4    4   24    17
# 2   428  ...    0.778   11   49   60   65   14    5   28   45   108
# 3  2669  ...    0.500  391  369  760  124  117   76  135  204  1108
# 4  1913  ...    0.735  165  432  597  184   71   65  121  203   729
#
# [5 rows x 32 columns]

# %%
player_data['player_lastname'] = player_data['player_lastname'].str.normalize('NFKD').str.encode('ascii', errors='ignore').str.decode('utf-8')

# %%
player_data['player_firstname'] = player_data['player_firstname'].str.normalize('NFKD').str.encode('ascii', errors='ignore').str.decode('utf-8')

# %%
player_data
# Out:
#      player_id player_lastname player_firstname  season pos  age   tm   g  gs  \
# 0    abrinal01         Abrines             Alex    2019  SG   25  OKC  31   2
# 1      acyqu01             Acy           Quincy    2019  PF   28  PHO  10   0
# 2    adamsja01           Adams           Jaylen    2019  PG   22  ATL  34   1
# 3    adamsst01           Adams           Steven    2019   C   25  OKC  80  80
# 4    adebaba01         Adebayo              Bam    2019   C   21  MIA  82  28
# 5     adelde01            Adel             Deng    2019  SF   21  CLE  19   3
# 6    akoonde01   Akoon-Purcell         DeVaughn    2019  SG   25  DEN   7   0
# 7    aldrila01        Aldridge         LaMarcus    2019   C   33  SAS  81  81
# 8    alkinra01          Alkins            Rawle    2019  SG   21  CHI  10   1
# 9    allengr01           Allen          Grayson    2019  SG   23  UTA  38   2
# 10   allenja01           Allen          Jarrett    2019   C   20  BRK  80  80
# ...

# %%
player_data.to_csv(r'player_stats_2019_normal.csv', index=False)
